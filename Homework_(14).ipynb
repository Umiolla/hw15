# %% [markdown]
# # HOMEWORK 14
#
# In this homework we will be working with the Fashion MNIST dataset. You will be given a classifier which suffers from considerable overfitting. Your objective will be to employ regularization techniques to mitigate the overfitting problem.
#
# Let's start with the usual imports.

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Dense, Dropout, Flatten, Input, MaxPooling2D, BatchNormalization
from tensorflow.keras import Model
from tensorflow.keras.callbacks import EarlyStopping
from time import time

from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# Set the seeds for reproducibility
from numpy.random import seed
from tensorflow.random import set_seed
seed_value = 1234578790
seed(seed_value)
set_seed(seed_value)

# %% [markdown]
# ### Dataset
#
# The MNIST fashgion dataset [link](https://github.com/zalandoresearch/fashion-mnist) was build by Zalando Reasearch tem consists of monochrome images of different type of clothing, namely:
# * 0	T-shirt/top
# * 1	Trouser
# * 2	Pullover
# * 3	Dress
# * 4	Coat
# * 5	Sandal
# * 6	Shirt
# * 7	Sneaker
# * 8	Bag
# * 9	Ankle boot
#
# It is also one of the Keras built-in datasets. Let's load the images and quickly inspect it.

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# Dataset params
num_classes = 10
size = x_train.shape[1]

print('Train set:   ', len(y_train), 'samples')
print('Test set:    ', len(y_test), 'samples')
print('Sample dims: ', x_train.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Train set:    60000 samples
# Test set:     10000 samples
# Sample dims:  (60000, 28, 28)

# %% [markdown]
# Let's visualise some random samples.

# %%
cnt = 1
for r in range(3):
    for c in range(6):
        idx = np.random.randint(len(x_train))
        plt.subplot(3,6,cnt)
        plt.imshow(x_train[idx, ...], cmap='gray')
        plt.title(y_train[idx])
        cnt = cnt + 1

# %% [markdown]
# ### Building the Classifier
#
# We are now going to build the baseline classifier that you will use throughout this homework.

# %%
# Data normalization
x_train = x_train/255
x_test = x_test/255

# %%
inputs = Input(shape=(28, 28, 1))
net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = Flatten()(net)
net = Dense(128)(net)
outputs = Dense(10, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 28, 28, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       3,211,392 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,213,002 (12.26 MB)
#  Trainable params: 3,213,002 (12.26 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
epochs = 50
batch_size = 64

model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 76s 78ms/step - accuracy: 0.8162 - loss: 0.5556 - val_accuracy: 0.8778 - val_loss: 0.3360
# Epoch 2/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 80ms/step - accuracy: 0.8985 - loss: 0.2840 - val_accuracy: 0.8852 - val_loss: 0.3127
# Epoch 3/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 79s 77ms/step - accuracy: 0.9138 - loss: 0.2382 - val_accuracy: 0.8894 - val_loss: 0.3104
# Epoch 4/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 76ms/step - accuracy: 0.9267 - loss: 0.2039 - val_accuracy: 0.8890 - val_loss: 0.3220
# Epoch 5/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 72s 77ms/step - accuracy: 0.9362 - loss: 0.1788 - val_accuracy: 0.8891 - val_loss: 0.3396
# Epoch 6/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 78ms/step - accuracy: 0.9435 - loss: 0.1574 - val_accuracy: 0.8892 - val_loss: 0.3637
# Epoch 7/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 77ms/step - accuracy: 0.9507 - loss: 0.1389 - val_accuracy: 0.8896 - val_loss: 0.3797
# Epoch 8/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 77ms/step - accuracy: 0.9565 - loss: 0.1228 - val_accuracy: 0.8876 - val_loss: 0.4137
# Epoch 9/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 77ms/step - accuracy: 0.9619 - loss: 0.1082 - val_accuracy: 0.8840 - val_loss: 0.4562
# Epoch 10/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 76ms/step - accuracy: 0.9656 - loss: 0.0960 - val_accuracy: 0.8836 - val_loss: 0.4879
# Epoch 11/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 72s 76ms/step - accuracy: 0.9696 - loss: 0.0887 - val_accuracy: 0.8811 - val_loss: 0.5381
# Epoch 12/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 77ms/step - accuracy: 0.9742 - loss: 0.0766 - val_accuracy: 0.8832 - val_loss: 0.5614
# Epoch 13/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 76ms/step - accuracy: 0.9743 - loss: 0.0721 - val_accuracy: 0.8869 - val_loss: 0.5557
# Epoch 14/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 77ms/step - accuracy: 0.9752 - loss: 0.0689 - val_accuracy: 0.8849 - val_loss: 0.5881
# Epoch 15/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 72s 77ms/step - accuracy: 0.9764 - loss: 0.0641 - val_accuracy: 0.8836 - val_loss: 0.6130
# Epoch 16/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 76ms/step - accuracy: 0.9790 - loss: 0.0566 - val_accuracy: 0.8797 - val_loss: 0.6861
# Epoch 17/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 72s 77ms/step - accuracy: 0.9799 - loss: 0.0555 - val_accuracy: 0.8824 - val_loss: 0.7181
# Epoch 18/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 77ms/step - accuracy: 0.9811 - loss: 0.0509 - val_accuracy: 0.8820 - val_loss: 0.7259
# Epoch 19/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 78ms/step - accuracy: 0.9826 - loss: 0.0467 - val_accuracy: 0.8853 - val_loss: 0.7289
# Epoch 20/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 73s 78ms/step - accuracy: 0.9842 - loss: 0.0423 - val_accuracy: 0.8852 - val_loss: 0.7748
# Epoch 21/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 77ms/step - accuracy: 0.9849 - loss: 0.0428 - val_accuracy: 0.8810 - val_loss: 0.8375
# Epoch 22/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 73s 78ms/step - accuracy: 0.9842 - loss: 0.0438 - val_accuracy: 0.8792 - val_loss: 0.9097
# Epoch 23/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 72s 77ms/step - accuracy: 0.9859 - loss: 0.0399 - val_accuracy: 0.8770 - val_loss: 0.9215
# Epoch 24/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 72s 77ms/step - accuracy: 0.9852 - loss: 0.0434 - val_accuracy: 0.8811 - val_loss: 0.9227
# Epoch 25/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 77ms/step - accuracy: 0.9863 - loss: 0.0385 - val_accuracy: 0.8811 - val_loss: 0.9044
# Epoch 26/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 77ms/step - accuracy: 0.9877 - loss: 0.0341 - val_accuracy: 0.8807 - val_loss: 0.9609
# Epoch 27/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 77ms/step - accuracy: 0.9883 - loss: 0.0326 - val_accuracy: 0.8847 - val_loss: 0.9628
# Epoch 28/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 78ms/step - accuracy: 0.9872 - loss: 0.0347 - val_accuracy: 0.8805 - val_loss: 0.9846
# Epoch 29/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 77ms/step - accuracy: 0.9875 - loss: 0.0351 - val_accuracy: 0.8824 - val_loss: 0.9436
# Epoch 30/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 77ms/step - accuracy: 0.9881 - loss: 0.0328 - val_accuracy: 0.8832 - val_loss: 0.9749
# Epoch 31/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 77ms/step - accuracy: 0.9885 - loss: 0.0316 - val_accuracy: 0.8829 - val_loss: 1.0182
# Epoch 32/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 78ms/step - accuracy: 0.9884 - loss: 0.0312 - val_accuracy: 0.8806 - val_loss: 1.1027
# Epoch 33/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 80s 77ms/step - accuracy: 0.9901 - loss: 0.0278 - val_accuracy: 0.8823 - val_loss: 1.0699
# Epoch 34/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 72s 77ms/step - accuracy: 0.9898 - loss: 0.0280 - val_accuracy: 0.8804 - val_loss: 1.0913
# Epoch 35/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 78ms/step - accuracy: 0.9913 - loss: 0.0243 - val_accuracy: 0.8802 - val_loss: 1.0897
# Epoch 36/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 75s 80ms/step - accuracy: 0.9904 - loss: 0.0275 - val_accuracy: 0.8804 - val_loss: 1.1516
# Epoch 37/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 79s 77ms/step - accuracy: 0.9898 - loss: 0.0279 - val_accuracy: 0.8765 - val_loss: 1.1510
# Epoch 38/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 77ms/step - accuracy: 0.9923 - loss: 0.0228 - val_accuracy: 0.8810 - val_loss: 1.1429
# Epoch 39/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 72s 77ms/step - accuracy: 0.9916 - loss: 0.0219 - val_accuracy: 0.8810 - val_loss: 1.1953
# Epoch 40/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 78ms/step - accuracy: 0.9921 - loss: 0.0210 - val_accuracy: 0.8802 - val_loss: 1.2104
# Epoch 41/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 77ms/step - accuracy: 0.9920 - loss: 0.0230 - val_accuracy: 0.8840 - val_loss: 1.1838
# Epoch 42/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 75s 80ms/step - accuracy: 0.9913 - loss: 0.0258 - val_accuracy: 0.8837 - val_loss: 1.2635
# Epoch 43/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 73s 78ms/step - accuracy: 0.9938 - loss: 0.0181 - val_accuracy: 0.8814 - val_loss: 1.2389
# Epoch 44/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 76ms/step - accuracy: 0.9907 - loss: 0.0252 - val_accuracy: 0.8797 - val_loss: 1.2744
# Epoch 45/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 76ms/step - accuracy: 0.9931 - loss: 0.0197 - val_accuracy: 0.8749 - val_loss: 1.3047
# Epoch 46/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 76ms/step - accuracy: 0.9933 - loss: 0.0199 - val_accuracy: 0.8798 - val_loss: 1.3226
# Epoch 47/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 78ms/step - accuracy: 0.9935 - loss: 0.0188 - val_accuracy: 0.8775 - val_loss: 1.3578
# Epoch 48/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 79ms/step - accuracy: 0.9928 - loss: 0.0196 - val_accuracy: 0.8777 - val_loss: 1.4013
# Epoch 49/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 79s 76ms/step - accuracy: 0.9933 - loss: 0.0201 - val_accuracy: 0.8818 - val_loss: 1.3144
# Epoch 50/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 77ms/step - accuracy: 0.9927 - loss: 0.0197 - val_accuracy: 0.8836 - val_loss: 1.3455

# %%
def plot_history(history):
    h = history.history
    epochs = range(len(h['loss']))

    plt.subplot(121), plt.plot(epochs, h['loss'], '.-', epochs, h['val_loss'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('loss')
    plt.legend(['Train', 'Validation'])
    plt.subplot(122), plt.plot(epochs, h['accuracy'], '.-',
                               epochs, h['val_accuracy'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'])

    print('Train Acc     ', h['accuracy'][-1])
    print('Validation Acc', h['val_accuracy'][-1])

plot_history(history)
# Out:
# Train Acc      0.9929166436195374
# Validation Acc 0.8835999965667725

# %% [markdown]
# As you can see, the classifier suffers from massive overfitting. The validation accuracy is around 88% while the training accuracy is close to 1.

# %% [markdown]
# ### Combat the Overfitting!
#
# Now it is your turn. Use the classifier as a baseline, include some regularization techniques and try to improve the classification performance. You can try any techniques you might see fit, e.g.,
# * Dropout
# * Batch normalization
# * Weight regularization
# * Data augmentation
# * Early stopping
# * Pooling
# * Reducing the number of parameters (the size of the network)
# * ...
#
# There are to objective you shall fulfill in order to successfully complete this homework:
# * The validation accuracy shall be above 91%
# * Your network (with all the regularizations applied) shall **not** be larger than the baseline

# %%
# Modify the baseline classifier in order to reduce the overfitting and make the performance more robust

inputs = Input(shape=(28, 28, 1))
net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = BatchNormalization()(net)
net = MaxPooling2D(pool_size=(2, 2))(net)
net = Dropout(0.25)(net)

net = Conv2D(64, kernel_size=(3, 3), activation="relu", padding='same')(net)
net = BatchNormalization()(net)
net = MaxPooling2D(pool_size=(2, 2))(net)
net = Dropout(0.25)(net)

net = Flatten()(net)
net = Dense(64, activation="relu")(net)
net = BatchNormalization()(net)
net = Dropout(0.5)(net)

outputs = Dense(10, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 28, 28, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 28, 28, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 14, 14, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 14, 14, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 7, 7, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 7, 7, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 3136)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 64)                  │         200,768 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 220,874 (862.79 KB)
#  Trainable params: 220,554 (861.54 KB)
#  Non-trainable params: 320 (1.25 KB)

# %%
model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer="adam",
    metrics=["accuracy"]
)

# %%
# Early stopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

# %%
# Train the network
history = model.fit(
    x_train, y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_test, y_test),
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 121s 125ms/step - accuracy: 0.7599 - loss: 0.7115 - val_accuracy: 0.8849 - val_loss: 0.3192
# Epoch 2/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 114s 122ms/step - accuracy: 0.8761 - loss: 0.3600 - val_accuracy: 0.8943 - val_loss: 0.2898
# Epoch 3/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 140s 120ms/step - accuracy: 0.8872 - loss: 0.3225 - val_accuracy: 0.9016 - val_loss: 0.2675
# Epoch 4/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 141s 119ms/step - accuracy: 0.8960 - loss: 0.2893 - val_accuracy: 0.9055 - val_loss: 0.2596
# Epoch 5/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 142s 119ms/step - accuracy: 0.9031 - loss: 0.2724 - val_accuracy: 0.9043 - val_loss: 0.2612
# Epoch 6/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 111s 119ms/step - accuracy: 0.9055 - loss: 0.2660 - val_accuracy: 0.9133 - val_loss: 0.2372
# Epoch 7/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 111s 119ms/step - accuracy: 0.9104 - loss: 0.2524 - val_accuracy: 0.9028 - val_loss: 0.2817
# Epoch 8/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 142s 119ms/step - accuracy: 0.9124 - loss: 0.2457 - val_accuracy: 0.9165 - val_loss: 0.2300
# Epoch 9/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 142s 119ms/step - accuracy: 0.9134 - loss: 0.2414 - val_accuracy: 0.9159 - val_loss: 0.2325
# Epoch 10/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 142s 119ms/step - accuracy: 0.9172 - loss: 0.2304 - val_accuracy: 0.9085 - val_loss: 0.2557
# Epoch 11/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 142s 119ms/step - accuracy: 0.9191 - loss: 0.2272 - val_accuracy: 0.9195 - val_loss: 0.2220
# Epoch 12/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 142s 119ms/step - accuracy: 0.9218 - loss: 0.2193 - val_accuracy: 0.9188 - val_loss: 0.2215
# Epoch 13/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 111s 119ms/step - accuracy: 0.9223 - loss: 0.2146 - val_accuracy: 0.9249 - val_loss: 0.2133
# Epoch 14/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 143s 119ms/step - accuracy: 0.9236 - loss: 0.2107 - val_accuracy: 0.9153 - val_loss: 0.2432
# Epoch 15/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 142s 119ms/step - accuracy: 0.9241 - loss: 0.2079 - val_accuracy: 0.9218 - val_loss: 0.2225
# Epoch 16/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 112s 119ms/step - accuracy: 0.9263 - loss: 0.2020 - val_accuracy: 0.9222 - val_loss: 0.2153
# Epoch 17/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 141s 118ms/step - accuracy: 0.9282 - loss: 0.2019 - val_accuracy: 0.9276 - val_loss: 0.2062
# Epoch 18/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 112s 119ms/step - accuracy: 0.9271 - loss: 0.2030 - val_accuracy: 0.9226 - val_loss: 0.2159
# Epoch 19/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 142s 119ms/step - accuracy: 0.9269 - loss: 0.1964 - val_accuracy: 0.9173 - val_loss: 0.2363
# Epoch 20/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 112s 119ms/step - accuracy: 0.9299 - loss: 0.1931 - val_accuracy: 0.9131 - val_loss: 0.2605
# Epoch 21/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 111s 118ms/step - accuracy: 0.9300 - loss: 0.1910 - val_accuracy: 0.9101 - val_loss: 0.2600
# Epoch 22/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 143s 119ms/step - accuracy: 0.9303 - loss: 0.1901 - val_accuracy: 0.8986 - val_loss: 0.2947

# %%
# Show the results

plot_history(history)
# Out:
# Train Acc      0.9300500154495239
# Validation Acc 0.8985999822616577

# %% [markdown]
# ### Questions
#
# **What have you done in order to improve the performance?**
#
#
# *   Added Batch Normalization to stabilize and speed up training.
# *   Introduced Dropout layers to reduce overfitting.
# *   Applied Max Pooling to reduce spatial dimensions and prevent overfitting.
# *   Reduced the size of the dense layer to limit the total parameter count.
# *   Used Early Stopping to prevent overtraining.
#
# **Have you tried configurations that did not work out?**
# *   I tried increasing the number of filters in convolutional layers, which increased overfitting.
# *   I also tried adding more dense layers, which made the model larger than the baseline.
# *   L2 regularization alone without dropout, but it was insufficient to fully mitigate overfitting.
